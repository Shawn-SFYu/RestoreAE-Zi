# %%
import os
print(os.sys.path)
# Out:
# ['/dli/task/nv', '/dli/assessment/notebook_helpers', '/usr/lib/python38.zip', '/usr/lib/python3.8', '/usr/lib/python3.8/lib-dynload', '', '/dli/task/nv/Qi/lib/python3.8/site-packages']

# %%
run denoise_dataset.py
# Out:
# Number of the class = 3751
# noisy shape torch.Size([1, 224, 224])
# original shape torch.Size([1, 1, 224, 224])
# original shape squeeze torch.Size([1, 224, 224])
